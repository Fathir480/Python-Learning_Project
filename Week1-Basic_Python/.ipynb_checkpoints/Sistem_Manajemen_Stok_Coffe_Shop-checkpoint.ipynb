# %% [markdown]
# ## Sistem Manajemen Stok Coffee Shop

# %%
jenis_kopi = []

def menu():
    print("\n--- Sistem Manajemen Stok Coffee Shop ---")
    print("-----------------------------------------")
    print("1. Lihat stok")
    print("2. Tambah stok")
    print("3. Cek ketersediaan")
    print("4. Hitung Kebutuhan")
    print("5. Keluar")

def menu_tambah():
    print("\nMenu Tambah Stok")
    print("a. tambah stok")
    print("b. tambah jenis kopi & stok\n")

def lihat_stok():
    

def tambah_stok():
    menu_tambah()
    pilih_tambah = input("Masukkan pilihan anda [a, b]: ")
    if pilih_tambah.lower() == "a":
        if jenis_kopi:
            kopi = input("Masukkan Jenis kopi: ")
            for nama, stok in jenis_kopi:
                if nama == kopi:
                    input_stok = int(input("Masukkan jumlah stok yang ingin ditambahkan (g): "))
                    stok += input_stok
                    print(f"Stok {kopi} berhasil ditambahkan")
                else:
                    print("Jenis kopi tidak tersedia")
        else:
            print("Daftar jenis kopi kosong")
    elif pilih_tambah.lower() == "b":
        kopi = input("Masukkan Jenis kopi: ")
        input_stok = int(input("Masukkan jumlah stok (g)"))
        jenis_kopi.append([kopi, input_stok])
        print(f"{kopi} dengan stok {input_stok} berhasil ditambahkan")

while True:
    menu()
    pilih = input("Masukkan pilihan anda [1-5]: ")
    if pilih == "2":
        tambah_stok()
    elif pilih == "5":
        break
    else:
        print("Input tidak valid")
# Out:
# --- Sistem Manajemen Stok Coffee Shop ---
# -----------------------------------------
# 1. Lihat stok
# 2. Tambah stok
# 3. Cek ketersediaan
# 4. Hitung Kebutuhan
# 5. Keluar
# Masukkan pilihan anda [1-5]:  2
# Menu Tambah Stok
# a. tambah stok
# b. tambah jenis kopi & stok
# Masukkan pilihan anda [a, b]:  b
# Masukkan Jenis kopi:  gayo
# Masukkan jumlah stok (g) 1000
# gayo dengan stok 1000 berhasil ditambahkan
#
# --- Sistem Manajemen Stok Coffee Shop ---
# -----------------------------------------
# 1. Lihat stok
# 2. Tambah stok
# 3. Cek ketersediaan
# 4. Hitung Kebutuhan
# 5. Keluar
# Masukkan pilihan anda [1-5]:  5
# [['gayo', 1000]]
