# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# ### variable and typedata

# %%
name = "Fathir" # string variable
age = 20 # integer
height = 173.5 # float
is_gamer = True # boolean

print("Name:", name)
print("Age:", age)
print("Height:", height)
print("Is_Gamer?", is_gamer)
# Out:
# Name: Fathir
# Age: 20
# Height: 173.5
# Is_Gamer? True

# %% [markdown]
# ### input function

# %%
username_input = input("Whats your name?")
print("Welcome", username_input)
# Out:
# Whats your name? Fathir
# Welcome Fathir

# %% [markdown]
# ### math

# %%
x = 5
y = 3

print(x + y)
print(x - y)
print(x * y)
print(x / y)
print(x // y)
print(x % y)
# Out:
# 8
# 2
# 15
# 1.6666666666666667
# 1
# 2

# %% [markdown]
# ### Desition

# %%
age = int(input("Enter your age: ")) #input only integer

if age >= 18:
    print("You are an adult")
elif age >= 13:
    print("You are a teenager")
else:
    print("You are a minor")
# Out:
# Enter your age:  20
# You are an adult

# %% [markdown]
# ### Loops

# %%
count = 0
while count < 5:
    print("Count is:", count)
    count += 1
# Out:
# Count is: 0
# Count is: 1
# Count is: 2
# Count is: 3
# Count is: 4

# %%
video_games = ["Game 1", "Game 2", "Game 3"]

for game in video_games:
    print(game)
# Out:
# Game 1
# Game 2
# Game 3

# %% [markdown]
# ### List

# %%
print(video_games[0])  # index start from 0
video_games.append("Game 4")

print(video_games)

video_games[1] = "Game two"

print(video_games)
# Out:
# Game 1
# ['Game 1', 'Game 2', 'Game 3', 'Game 4']
# ['Game 1', 'Game two', 'Game 3', 'Game 4']

# %% [markdown]
# ### Function

# %%
def say_hello(person_name):
    print("Hello " + person_name)

say_hello("Laura")

def sum(a, b):
    return a + b

result = sum(5,8)
print("Result: ", result)
# Out:
# Hello Laura
# Result:  13

# %% [markdown]
# ### Mini Project: Number Guessing Game

# %%
import random

secret_number = random.randint(1, 10)
attemps = 3

print("I`m thingking of a number 1 and 10")

while attemps > 0:
    guess = int(input("Take a Guess: "))
    if guess == secret_number:
        print("Congratullation! You guessed the number!")
        break
    elif guess < secret_number:
        print("too low! Try again.")
    else:
        print("too high! Try again.")
    attemps -= 1

if attemps == 0:
    print("Game Over!!!, Secret number: ", secret_number)
# Out:
# I`m thingking of a number 1 and 10
# Take a Guess:  3
# too low! Try again.
# Take a Guess:  5
# too low! Try again.
# Take a Guess:  8
# too high! Try again.
# Game Over!!!, Secret number:  7

# %%
# upgrade a project

import random

def generate_secret_number(level):
    if level == 1:
        secret_number = random.randint(1, 10)
        print("Easy level, 1 - 10")
    elif level == 2:
        secret_number = random.randint(1, 25)
        print("Medium level, 1 - 25")
    else:
        secret_number = random.randint(1, 50)
        print("Hard level, 1 - 50")
    return secret_number

print("-- Find a Sesret Number --")
print("--------------------------")
print("1. Easy")
print("2. Medium")
print("3. Hard")
level = int(input("Choise your level (1/2/3): "))
print()
secret = generate_secret_number(level)
change = 3
while change > 0:
    print("\nyour change: ", change)
    
    guess = int(input("Take a guess: "))
    if guess == secret:
        print("Congratullation! You guessed the number!")
        break
    elif guess < secret:
        print("too low! Try again.")
    else:
        print("too high! Try again.")
    change -= 1

if change == 0:
    print("Game Over!!!, Secret number: ", secret_number)
# Out:
# -- Find a Sesret Number --
# --------------------------
# 1. Easy
# 2. Medium
# 3. Hard
# Choise your level (1/2/3):  1
# Easy level, 1 - 10
#
# your change:  3
# Take a guess:  5
# Congratullation! You guessed the number!
