# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# ### variable and typedata

# %%
name = "Fathir" # string variable
age = 20 # integer
height = 173.5 # float
is_gamer = True # boolean

print("Name:", name)
print("Age:", age)
print("Height:", height)
print("Is_Gamer?", is_gamer)
# Out:
# Name: Fathir
# Age: 20
# Height: 173.5
# Is_Gamer? True

# %% [markdown]
# ### input function

# %%
username_input = input("Whats your name?")
print("Welcome", username_input)
# Out:
# Whats your name? Fathir
# Welcome Fathir

# %% [markdown]
# ### math

# %%
x = 5
y = 3

print(x + y)
print(x - y)
print(x * y)
print(x / y)
print(x // y)
print(x % y)
# Out:
# 8
# 2
# 15
# 1.6666666666666667
# 1
# 2

# %% [markdown]
# ### Desition

# %%
age = int(input("Enter your age: ")) #input only integer

if age >= 18:
    print("You are an adult")
elif age >= 13:
    print("You are a teenager")
else:
    print("You are a minor")
# Out:
# Enter your age:  15
# You are a teenager

# %% [markdown]
# ### Loops

# %%
count = 0
while count < 5:
    print("Count is:", count)
    count += 1
# Out:
# Count is: 0
# Count is: 1
# Count is: 2
# Count is: 3
# Count is: 4
