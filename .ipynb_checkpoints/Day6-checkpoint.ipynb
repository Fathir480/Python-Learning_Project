# %% [markdown]
# Day 6 - Basic Python Programing
# -------------------------------
#
# Main Topic: Function
#
# -> Sebuah Blok Code yang dirancang untuk melakukan tugas spesific
#
# Alasan menggunakan function:
# - Reusability
# - Modularitas
# - Abstraksi
#
# sintaks:
# ``` python
# # create function:
# def function_name():
#     # Code block
#
# # call function:
# function_name()
# ```

# %%
def greet():
    print("Helllo, Welcome to Python!")

greet()
greet()
# Out:
# Helllo, Welcome to Python!
# Helllo, Welcome to Python!

# %%
def greet_user(name):
    print(f"Hello, {name}!")

greet_user("Fathir")
# Out:
# Hello, Fathir!

# %%
def sum(a, b):
    result = a + b
    print(f"Result: {result}")

sum(3,2)
# Out:
# Result: 5

# %%
def multiply(a, b):
    return a * b # Gunakana return jika ingin mengembalikan nilai

result = multiply(3, 3)

print(result + 3)  # 9 + 3
# Out:
# 12

# %%
# Mini Project: Math Quiz Game

import random

def generate_questionn():
    num1 = random.randint(1, 10)
    num2 = random.randint(1, 10)
    operator = random.choice(['+', '-', '*'])

    if operator == '+':
        result = num1 + num2
    elif operator == '-':
        result = num1 - num2
    else:
        result = num1 * num2

    return f"{num1} {operator} {num2}", result

def math_quiz():
    score = 0
    rounds = 3

    while rounds > 0:
        question, answer = generate_questionn()
        user_answer = int(input(f"\nQuestion : {question} = "))

        if user_answer == answer:
            print("Correct!")
            score += 1
        else:
            print(f"Wrong! The correct answer is: {answer}")
        rounds -= 1

    print("\nGame Over!")
    print(f"Final score: {score}/{rounds}")

math_quiz()
# Out:
# Question : 9 + 5 =  14
# Correct!
# Question : 9 * 10 =  90
# Correct!
# Question : 7 * 2 =  14
# Correct!
#
# Game Over!
# Final score: 3/0
