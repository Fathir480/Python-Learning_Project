# %% [markdown]
# ### What's variable

# %%
name = "Fathir"
nameOfPerson = "Laura"
age = 20

# %% [markdown]
# ### Data Types

# %%
#String
name = "Fathir"

# integer
age = 20

# float
height = 173.5

# boolean
is_student = True

print(type(name))
print(type(age))
print(type(height))
print(type(is_student))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# ### Type Convertion

# %%
age = "20"
myAge = int(age)

print(type(age))
print(type(myAge))
# Out:
# <class 'str'>
# <class 'int'>

# %% [markdown]
# ### String Formating

# %%
name = "Fathir"

print("Hello, " + name + "!")
print("Hello,", name, "!")
print(f"Helllo, {name}!")
# Out:
# Hello, Fathir!
# Hello, Fathir !
# Helllo, Fathir!

# %% [markdown]
# ### Personalized Greeting Program

# %%
name = input("What's your name? ")
age = int(input("How old are you? "))
color = input("What is your favorite color? ")

print("\n--- Personalized Greeting ---")
print(f"Hello, {name}!")
print(f"You are {age} years old and {color} is a beautiful color!")
print(f"You're now ready to start your Python adventure")
# Out:
# What's your name?  Albert Camus
# How old are you?  30
# What is your favorite color?  black
# --- Personalized Greeting ---
# Hello, Albert Camus!
# You are 30 years old and black is a beautiful color!
# You're now ready to start your Python adventure
