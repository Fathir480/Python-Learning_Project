# %% [markdown]
# ### What is print a statment

# %%
print("Hello, Python world!")
# Out:
# Hello, Python world!

# %% [markdown]
# ### How to use print with text and numbers

# %%
print("The number is", 4)
print("2 + 2 =", 3+2)

# %% [markdown]
# ### String Formatting for dynamic messages

# %%
name = "Fathir"
print(f"Hello, {name}! Welcome to Python Programming")
# Out:
# Hello, Fathir! Welcome to Python Programming

# %% [markdown]
# ### Using user input with print

# %%
user_name = input("What's your name? ")
print(f"Hello, {user_name}! Welcome to Python Programming")
# Out:
# What`s your name?  Laura
# Hello, Laura! Welcome to Python Programming

# %% [markdown]
# ### Mini-Project: Welcome Message Generator

# %%
name = input("What's your name? ")
hobby = input("What's your favorite hobby? ")

print("\n--- Welcome Massage ---")
print(f"Hello, {name}!")
print(f"Welcome to the world of Python Programming")
print(f"It's great to know taht you love {hobby}.")
print(f"Get ready to builld something amazing today")
# Out:
# What's your name?  Fathir
# What's your favorite hobby?  Game
# --- Welcome Massage ---
# Hello, Fathir!
# Welcome to the world of Python Programming
# It's great to know taht you love Game.
# Get ready to builld something amazing today
