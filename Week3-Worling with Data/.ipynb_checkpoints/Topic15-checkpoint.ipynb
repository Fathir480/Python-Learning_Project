# %% [markdown]
# ### Reading File in Python
#
# pada topik ini akan membahas bagaimana cara python membaca file eksternal.
#
# __sintaks dasarnya:__
# ``` python
# file = open('contoh.txt', 'r') # Membuka file dalam mode baca / 'r'
#
# isi = file.read() # Membaca isi file
# print(isi)
#
# file.close() # Menutup file
# ```
#
# __Beberapa cara membaca file di python:__
# - .read()      : Membaca seluruh file sekaligus
# - .readline()  : Membaca baris per baris
# - .readlines() : Membaca semua baris ke dalam bentuk list
#
# __Penggunaan with (Context Manager)__
#
# > fitur ini membuat python dapat menutup file secara otomatis setelah blok kode di jalankan. Python menjamin file pasti tertutup secara otomatis secara bersih, apapun yang terjadi di dalam blok kodenya.
# ``` python
# # contoh
# with open('data.txt', 'r', encoding='utf-8') as file:
#     isi_file = file.read()
#     print(isi_file)
# ```

# %%
with open("filename.txt", "r") as file:
    content = file.read()
    print(f"- {content}")

# %%
with open("filename.txt", "r") as file:
    for line in file:
        print(f"- {line.strip()}")
# Out:
# - Recipe: Pancakes
# - Ingredients: Flour, Milk, Eggs, Sugar
# - Instructions: Mix and fry

# %%
try:
    with open("filename.txt", "r") as file:
        content = file.read()
        print(content)
except FileNotFoundError:
    print("File not found.")
# Out:
# Recipe: Pancakes
# Ingredients: Flour, Milk, Eggs, Sugar
# Instructions: Mix and fry

# %%
# mini project

def load_recipes(file_path):
    try:
        with open(file_path, "r") as file:
            content = file.read()
            recipes = content.split("\n\n")
            recipe_dict = {}
            for recipe in recipes:
                lines = recipe.split("\n")
                if len(lines) >= 3:
                    name = lines[0].strip()
                    ingredients = lines[1].replace('Ingredients: ', '').strip()
                    instructions = lines[2].replace('Instructions: ', '').strip()
                    recipe_dict[name] = {"ingredients": ingredients, "instructions": instructions}
            return recipe_dict
    except FileNotFoundError:
        print("File not found")
        return {}

def show_menu():
    print("\n--- Recipe Viewer Menu ---")
    print("1. View Recipe by Name")
    print("2. List All Recipes")
    print("3. Exit")

def view_recipe(recipes):
    name = input("Enter the name of the recipe: ").strip()
    if name in recipes:
        print(f"\n--- Recipe {name} Details ---")
        print(f"Ingredients: {recipes[name]['ingredients']}")
        print(f"Instructions: {recipes[name]['instructions']}")
    else:
        print("Recipe  not found")

recipe_file = "recipes.txt"
recipes = load_recipes(recipe_file)

while True:
    show_menu()
    choice = input("Enter yout choice (1-3): ")

    if choice == '1':
        view_recipe(recipes)
    elif choice == '2':
        print("\n--- All Recipes ---")
        for name in recipes:
            print(name)
    elif choice == '3':
        print("Exiting the program")
        break
    else:
        print("Invalid choice. Please try again")
# Out:
# --- Recipe Viewer Menu ---
# 1. View Recipe by Name
# 2. List All Recipes
# 3. Exit
# Enter yout choice (1-3):  2
# --- All Recipes ---
# Pancakes
# Salad
# Smoothie
#
# --- Recipe Viewer Menu ---
# 1. View Recipe by Name
# 2. List All Recipes
# 3. Exit
# Enter yout choice (1-3):  1
# Enter the name of the recipe:  Salad
# --- Recipe Salad Details ---
# Ingredients: Lettuce, Tomato, Cucumber, Dressing
# Instructions: Chop ingredients and mix
#
# --- Recipe Viewer Menu ---
# 1. View Recipe by Name
# 2. List All Recipes
# 3. Exit
# Enter yout choice (1-3):  3
# Exiting the program
