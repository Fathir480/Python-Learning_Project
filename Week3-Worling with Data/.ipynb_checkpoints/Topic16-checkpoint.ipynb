# %%
with open("journal.txt", "w") as file: 
    file.write("Hari ini saya belajar cara membuat dan menulis file dengan python")

# %%
with open("journal.txt", "a") as file:
    file.write("\nNama saya fathir")
