# %%
def math_operations(a, b):
    add = a + b
    sub = a - b
    multiply = a * b
    division = a / b
    return add, sub, multiply, division

add, sub, multiply, division = math_operations(10, 5)

print(sub)
# Out:
# 5

# %%
# Temperatur Converter

def celcius_to_fahrenheit(celcius):
    return (celcius * 9/5) + 32

def celcius_to_kelvin(celcius):
    return celcius + 273.15

def fahrenheit_to_celcius(fahrenheit):
    return (fahrenheit - 32) * 5/9

def fahrenheit_to_kelvin(fahrenheit):
    return (fahrenheit - 32) * 5/9 + 273.15

def kelvin_to_celcius(kelvin):
    return kelvin - 273.15

def kelvin_to_fahrenheit(kelvin):
    return  (kelvin - 273.15) * 9/5 + 32

def show_menu():
    print("\n--- Temperature Converter Menu ---")
    print("1, Celcius to Fahrenheit & Kelvin")
    print("2. Fahrenheit to Celcius & Kelvin")
    print("3. Kelvin to Celcius & Fahrenheit")
    print("4. Exit")

while True:
    show_menu()
    choice = input("Enter your choice (1-4): ")
    if choice == "1":
        celcius = float(input("Enter temperature in Celcius: "))
        print(f"Fahrenheit: {celcius_to_fahrenheit(celcius):.2f}")
        print(f"Kelvin: {celcius_to_kelvin(celcius):.2f}")
    elif choice == "2":
        fahrenheit = float(input("Enter temperature in Fahrenheit: "))
        print(f"Celcius: {fahrenheit_to_celcius(fahrenheit):.2f}")
        print(f"Kelvin: {fahrenheit_to_kelvin(celcius):.2f}")
    elif choice == "3":
        kelvin = float(input("Enter temperature in Kelvin: "))
        print(f"Celcius: {kelvin_to_celcius(kelvin):.2f}")
        print(f"Fahrenheit: {kelvin_to_fahrenheit(kelvin):.2f}")
    elif choice == "4":
        print("Exiting the program. Goodbye!")
        break
    else:
        print("Invalid choice. Please selesct a valid option")
# Out:
# --- Temperature Converter Menu ---
# 1, Celcius to Fahrenheit & Kelvin
# 2. Fahrenheit to Celcius & Kelvin
# 3. Kelvin to Celcius & Fahrenheit
# 4. Exit
# Enter your choice (1-4):  1
# Enter temperature in Celcius:  30
# Fahrenheit: 86.00
# Kelvin: 303.15
#
# --- Temperature Converter Menu ---
# 1, Celcius to Fahrenheit & Kelvin
# 2. Fahrenheit to Celcius & Kelvin
# 3. Kelvin to Celcius & Fahrenheit
# 4. Exit
# Enter your choice (1-4):  2
# Enter temperature in Fahrenheit:  60
# Celcius: 15.56
# Kelvin: 272.04
#
# --- Temperature Converter Menu ---
# 1, Celcius to Fahrenheit & Kelvin
# 2. Fahrenheit to Celcius & Kelvin
# 3. Kelvin to Celcius & Fahrenheit
# 4. Exit
# Enter your choice (1-4):  3
# Enter temperature in Kelvin:  274
# Celcius: 0.85
# Fahrenheit: 33.53
#
# --- Temperature Converter Menu ---
# 1, Celcius to Fahrenheit & Kelvin
# 2. Fahrenheit to Celcius & Kelvin
# 3. Kelvin to Celcius & Fahrenheit
# 4. Exit
# Enter your choice (1-4):  4
# Exiting the program. Goodbye!
